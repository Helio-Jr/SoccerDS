# %%
#import modules
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.offsetbox import OffsetImage, AnnotationBbox

# %%
#Printng the dataset 
df = pd.read_csv('tabela_oitava_rodada.csv')
df
# Out:
#     Rk             Squad  MP  W  D  L  GF  GA  GD  Pts  Pts/MP    xG   xGA  \
# 0    1     Botafogo (RJ)   8  7  0  1  16   6  10   21    2.63  12.7   9.9
# 1    2         Palmeiras   8  4  4  0  17   7  10   16    2.00  13.7   6.0
# 2    3         São Paulo   8  4  3  1  14   7   7   15    1.88  11.8   8.0
# 3    4  Atlético Mineiro   8  4  2  2  12   7   5   14    1.75  12.1   7.5
# 4    5            Grêmio   8  4  2  2  12  11   1   14    1.75   8.8  12.9
# 5    6          Cruzeiro   8  4  1  3  12   7   5   13    1.63  12.8  10.8
# 6    7          Flamengo   8  4  1  3  14  10   4   13    1.63  15.2   8.6
# 7    8        Fluminense   8  4  1  3  12   8   4   13    1.63  11.4  13.8
# 8    9         Fortaleza   8  3  4  1  12   6   6   13    1.63  15.0   6.6
# 9   10        Bragantino   8  3  4  1  13  11   2   13    1.63  11.8  10.3
# 10  11    Atl Paranaense   8  4  0  4  11  11   0   12    1.50   9.7   8.9
# ...

# %%
#Select columns
df = df[['Squad', 'GF', 'GA', 'xG', 'xGA']]

# %%
#Renaming clubs
df.iloc[0, 0] = df.iloc[0, 0].replace('Botafogo (RJ)', 'Botafogo')
df.iloc[10,0] = df.iloc[10,0].replace('Atl Paranaense', 'Athletico')
df.iloc[18,0] = df.iloc[18,0].replace('América (MG)', 'América Mineiro')
df.iloc[9,0] = df.iloc[9,0].replace('RBBragantino', 'Bragantino')
df.iloc[4,0] = df.iloc[4,0].replace('Grêmio', 'Gremio')

# %%
#Creating the image path column
df['path'] = df['Squad'] + '.png'
df
# Out:
# /tmp/ipykernel_10756/3256707330.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['path'] = df['Squad'] + '.png'
#                Squad  GF  GA    xG   xGA                  path
# 0           Botafogo  16   6  12.7   9.9          Botafogo.png
# 1          Palmeiras  17   7  13.7   6.0         Palmeiras.png
# 2          São Paulo  14   7  11.8   8.0         São Paulo.png
# 3   Atlético Mineiro  12   7  12.1   7.5  Atlético Mineiro.png
# 4             Gremio  12  11   8.8  12.9            Gremio.png
# 5           Cruzeiro  12   7  12.8  10.8          Cruzeiro.png
# 6           Flamengo  14  10  15.2   8.6          Flamengo.png
# 7         Fluminense  12   8  11.4  13.8        Fluminense.png
# ...

# %%
#Plotting a simple scatter
fig, ax = plt.subplots(figsize=(6, 4), dpi=120)
ax.scatter(df['xG'], df['xGA'])

# %%
#Plotting the scatter with images

fig, ax = plt.subplots(figsize=(6, 4), dpi=120)
ax.scatter(df['xG'], df['xGA'], color='white')

img = 'escudos/'

def getImage(path):
    return OffsetImage(plt.imread(img + path), zoom=.05, alpha = 1)

for index, row in df.iterrows():
    ab = AnnotationBbox(getImage(row['path']), (row['xG'], row['xGA']), frameon=False)
    ax.add_artist(ab)

# %% [markdown]
# ## Scatter XGoals

# %%
# Set font and background colour
plt.rcParams.update({'font.monospace':'Courier'})
bgcol = '#ebffde'

# Create initial plot
fig, ax = plt.subplots(figsize=(6, 4), dpi=120)
fig.set_facecolor(bgcol)
ax.set_facecolor(bgcol)
ax.scatter(df['xG'], df['xGA'], c=bgcol)

# Change plot spines
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['left'].set_color('#ccc8c8')
ax.spines['bottom'].set_color('#ccc8c8')

# Change ticks
plt.tick_params(axis='x', labelsize=12, color='#ccc8c8')
plt.tick_params(axis='y', labelsize=12, color='#ccc8c8')

# Plot badges
def getImage(path):
    return OffsetImage(plt.imread(img + path), zoom=.05, alpha = 1)

for index, row in df.iterrows():
    ab = AnnotationBbox(getImage(row['path']), (row['xG'], row['xGA']), frameon=False)
    ax.add_artist(ab)

# Add average lines
plt.hlines(df['xGA'].mean(), df['xG'].min(), df['xG'].max(), color='#8B0000')
plt.vlines(df['xG'].mean(), df['xGA'].min(), df['xGA'].max(), color='#000080')

# Text

## Title & comment
fig.text(.15,.98,'Análise de gols esperados',size=20)
fig.text(.15,.92,'Brasileirão 2023 - Rodada 8', size=12, color = '#808080')

## Axes titles
fig.text(.03,.4,'xG contra', size=9, color='#1C1C1C',rotation=90)
fig.text(.45,0.001,'xG pró', size=9, color='#1C1C1C')

## Avg line explanation
fig.text(.76,.5,'Média xG contra', size=6, color='#8B0000')
fig.text(.44,.17,'Média xG pró', size=6, color='#000080',rotation=90)

## Save plot
plt.savefig('xGChart.png', dpi=1200, bbox_inches = "tight")

# %% [markdown]
# ## Scatter Goals

# %%
# Create another initial plot
fig, ax = plt.subplots(figsize=(6, 4), dpi=120)
fig.set_facecolor(bgcol)
ax.set_facecolor(bgcol)
ax.scatter(df['GF'], df['GA'], c=bgcol)

# Change plot spines
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['left'].set_color('#ccc8c8')
ax.spines['bottom'].set_color('#ccc8c8')

# Change ticks
plt.tick_params(axis='x', labelsize=12, color='#ccc8c8')
plt.tick_params(axis='y', labelsize=12, color='#ccc8c8')

# Plot badges
def getImage(path):
    return OffsetImage(plt.imread(img + path), zoom=.05, alpha = 1)

for index, row in df.iterrows():
    ab = AnnotationBbox(getImage(row['path']), (row['GF'], row['GA']), frameon=False)
    ax.add_artist(ab)

# Add average lines
#plt.hlines(df['GA'].mean(), df['GF'].min()-1, df['GF'].max()+1, color='#8B0000')
#plt.vlines(df['GF'].mean(), df['GA'].min()-1, df['GA'].max()+1, color='#000080')
plt.hlines(df['GA'].mean(), df['GF'].min(), df['GF'].max(), color='#8B0000')
plt.vlines(df['GF'].mean(), df['GA'].min(), df['GA'].max(), color='#000080')

# Text

## Title & comment
fig.text(.15,.98,'Análise de gols reais',size=20)
fig.text(.15,.92,'Brasileirão 2023 - Rodada 8', size=12, color='#808080')

## Axes titles
fig.text(.03,.4,'Gols contra', size=9, color='#1C1C1C',rotation=90)
fig.text(.4,0.001,'Gols pró', size=9, color='#1C1C1C')

## Avg line explanation
fig.text(.7196,.4,'Média Gols contra', size=6, color='#8B0000')
fig.text(.39,.17,'Média Gols pró', size=6, color='#000080',rotation=90)

## Save plot
plt.savefig('GChart.png', dpi=1200, bbox_inches = "tight")
